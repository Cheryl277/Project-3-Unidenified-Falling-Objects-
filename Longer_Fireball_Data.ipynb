# %%
## Import the dependencies
from geopy.geocoders import GoogleV3
from lat_lon_parser import parse
import pandas as pd, requests, time
import warnings
import numpy as np
import pyproj
import datetime as dt
import geopandas as GeoDataFrame

from functools import partial
from pyproj import Proj, transform

## Import api key
from config import map_key
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15584\2246616713.py in <module>
#      13
#      14 ## Import api key
# ---> 15 from config import map_key
#
# ImportError: cannot import name 'map_key' from 'config' (C:\Users\emich\anaconda3\lib\site-packages\config\__init__.py)

# %% [markdown]
# # 1. Setup

# %% [markdown]
# ### 1.1 Import the Data

# %%
df = pd.read_csv (r'C:\Users\emich\Desktop\penn data science bootcamp\Project 3\Project-3-\Resources\Longer_Fireball_Data.csv')
df
# Out:
#     Peak Brightness Date/Time (UT) Latitude (deg.) Longitude (deg.)  \
# 0              2023-04-01 00:02:03           16.8S            76.0E
# 1              2023-03-20 06:53:23           23.7S           132.6E
# 2              2023-03-11 08:21:28           74.7S            79.5E
# 3              2023-03-03 02:53:54           40.1N            87.4E
# 4              2023-02-19 06:15:34            7.9N           109.9E
# ..                             ...             ...              ...
# 946            1993-11-29 17:48:41           26.5N            78.3E
# 947            1993-10-31 03:39:27           51.3N           100.9W
# 948            1991-10-04 09:22:47           78.7N             6.3E
# 949            1990-10-01 03:51:47            7.5N           142.8E
# 950            1988-04-15 03:03:10            4.1S           124.3E
#
#      Altitude (km)  Velocity (km/s)    vx    vy   vz  \
# 0             61.8             46.4  21.4 -40.6  7.1
# 1             34.8              NaN   NaN   NaN  NaN
# 2             32.0              NaN   NaN   NaN  NaN
# 3             32.0             25.3  16.1 -19.3  2.6
# 4             37.0             23.0  -1.1 -22.9  1.2
# ..             ...              ...   ...   ...  ...
# 946            NaN              NaN   NaN   NaN  NaN
# 947            NaN              NaN   NaN   NaN  NaN
# 948            NaN              NaN   NaN   NaN  NaN
# 949            NaN              NaN   NaN   NaN  NaN
# 950            NaN              NaN   NaN   NaN  NaN
#
#      Total Radiated Energy (J)  Calculated Total Impact Energy (kt)
# 0                 2.400000e+10                                0.086
# 1                 2.700000e+10                                0.095
# 2                 4.440000e+11                                1.100
# 3                 6.400000e+10                                0.200
# 4                 2.030000e+11                                0.570
# ..                         ...                                  ...
# 946               2.600000e+10                                0.092
# 947               4.000000e+10                                0.130
# 948               5.500000e+11                                1.400
# 949               2.500000e+12                                5.200
# 950               7.580000e+12                               14.000
#
# [951 rows x 10 columns]

# %%
df.to_json(r'C:\Users\emich\Desktop\penn data science bootcamp\Project 3\Project-3-\Resources\Longer_Fireball_Data.json')

# %%
## Review the data type of each column
df.dtypes
# Out:
# Peak Brightness Date/Time (UT)          object
# Latitude (deg.)                         object
# Longitude (deg.)                        object
# Altitude (km)                          float64
# Velocity (km/s)                        float64
# vx                                     float64
# vy                                     float64
# vz                                     float64
# Total Radiated Energy (J)              float64
# Calculated Total Impact Energy (kt)    float64
# dtype: object

# %% [markdown]
# # 2. Data Cleaning

# %% [markdown]
# ### 2.1 Remove the Unwanted Columns and Rows

# %%
## Drop all null values
fireball_df = df.dropna()
fireball_df
# Out:
#     Peak Brightness Date/Time (UT) Latitude (deg.) Longitude (deg.)  \
# 0              2023-04-01 00:02:03           16.8S            76.0E
# 3              2023-03-03 02:53:54           40.1N            87.4E
# 4              2023-02-19 06:15:34            7.9N           109.9E
# 5              2023-02-14 22:55:25           48.0S            53.3W
# 8              2023-01-17 06:56:59           33.1N           173.7W
# ..                             ...             ...              ...
# 680            2004-04-22 04:21:49           44.3S            83.3E
# 681            2004-04-06 03:24:49           12.0S           162.8E
# 692            2003-11-10 13:54:06           64.5S           136.2E
# 697            2003-09-27 12:59:02           21.0N            86.6E
# 857            1998-01-04 23:00:27           35.1S            33.4E
#
#      Altitude (km)  Velocity (km/s)    vx    vy    vz  \
# 0             61.8             46.4  21.4 -40.6   7.1
# 3             32.0             25.3  16.1 -19.3   2.6
# 4             37.0             23.0  -1.1 -22.9   1.2
# 5             32.3             15.6 -15.1   3.7  -0.9
# 8             38.0             14.2   7.8  -5.6 -10.5
# ..             ...              ...   ...   ...   ...
# 680           29.6             16.3   8.5 -12.1  -6.8
# 681           35.0             25.6  10.5 -23.2  -2.9
# 692           23.0             20.1  14.8  -8.7  10.4
# 697           26.0             18.2  -1.0  -5.4 -17.3
# 857           30.0             17.1   6.0 -10.6  12.0
#
#      Total Radiated Energy (J)  Calculated Total Impact Energy (kt)
# 0                 2.400000e+10                                0.086
# 3                 6.400000e+10                                0.200
# 4                 2.030000e+11                                0.570
# 5                 1.840000e+11                                0.520
# 8                 2.900000e+10                                0.100
# ..                         ...                                  ...
# 680               6.240000e+11                                1.500
# 681               4.330000e+11                                1.100
# 692               5.180000e+11                                1.300
# 697               2.150000e+12                                4.600
# 857               7.400000e+10                                0.230
#
# [285 rows x 10 columns]

# %%
## Drop 'vx', 'vy', 'vz' columns
fireball_df.pop('vx')
fireball_df
# Out:
#     Peak Brightness Date/Time (UT) Latitude (deg.) Longitude (deg.)  \
# 0              2023-04-01 00:02:03           16.8S            76.0E
# 3              2023-03-03 02:53:54           40.1N            87.4E
# 4              2023-02-19 06:15:34            7.9N           109.9E
# 5              2023-02-14 22:55:25           48.0S            53.3W
# 8              2023-01-17 06:56:59           33.1N           173.7W
# ..                             ...             ...              ...
# 680            2004-04-22 04:21:49           44.3S            83.3E
# 681            2004-04-06 03:24:49           12.0S           162.8E
# 692            2003-11-10 13:54:06           64.5S           136.2E
# 697            2003-09-27 12:59:02           21.0N            86.6E
# 857            1998-01-04 23:00:27           35.1S            33.4E
#
#      Altitude (km)  Velocity (km/s)    vy    vz  Total Radiated Energy (J)  \
# 0             61.8             46.4 -40.6   7.1               2.400000e+10
# 3             32.0             25.3 -19.3   2.6               6.400000e+10
# 4             37.0             23.0 -22.9   1.2               2.030000e+11
# 5             32.3             15.6   3.7  -0.9               1.840000e+11
# 8             38.0             14.2  -5.6 -10.5               2.900000e+10
# ..             ...              ...   ...   ...                        ...
# 680           29.6             16.3 -12.1  -6.8               6.240000e+11
# 681           35.0             25.6 -23.2  -2.9               4.330000e+11
# 692           23.0             20.1  -8.7  10.4               5.180000e+11
# 697           26.0             18.2  -5.4 -17.3               2.150000e+12
# 857           30.0             17.1 -10.6  12.0               7.400000e+10
#
#      Calculated Total Impact Energy (kt)
# 0                                  0.086
# 3                                  0.200
# 4                                  0.570
# 5                                  0.520
# 8                                  0.100
# ..                                   ...
# 680                                1.500
# 681                                1.100
# 692                                1.300
# 697                                4.600
# 857                                0.230
#
# [285 rows x 9 columns]

# %%
## Drop 'vx', 'vy', 'vz' columns
fireball_df.pop('vy')
fireball_df
# Out:
#     Peak Brightness Date/Time (UT) Latitude (deg.) Longitude (deg.)  \
# 0              2023-04-01 00:02:03           16.8S            76.0E
# 3              2023-03-03 02:53:54           40.1N            87.4E
# 4              2023-02-19 06:15:34            7.9N           109.9E
# 5              2023-02-14 22:55:25           48.0S            53.3W
# 8              2023-01-17 06:56:59           33.1N           173.7W
# ..                             ...             ...              ...
# 680            2004-04-22 04:21:49           44.3S            83.3E
# 681            2004-04-06 03:24:49           12.0S           162.8E
# 692            2003-11-10 13:54:06           64.5S           136.2E
# 697            2003-09-27 12:59:02           21.0N            86.6E
# 857            1998-01-04 23:00:27           35.1S            33.4E
#
#      Altitude (km)  Velocity (km/s)    vz  Total Radiated Energy (J)  \
# 0             61.8             46.4   7.1               2.400000e+10
# 3             32.0             25.3   2.6               6.400000e+10
# 4             37.0             23.0   1.2               2.030000e+11
# 5             32.3             15.6  -0.9               1.840000e+11
# 8             38.0             14.2 -10.5               2.900000e+10
# ..             ...              ...   ...                        ...
# 680           29.6             16.3  -6.8               6.240000e+11
# 681           35.0             25.6  -2.9               4.330000e+11
# 692           23.0             20.1  10.4               5.180000e+11
# 697           26.0             18.2 -17.3               2.150000e+12
# 857           30.0             17.1  12.0               7.400000e+10
#
#      Calculated Total Impact Energy (kt)
# 0                                  0.086
# 3                                  0.200
# 4                                  0.570
# 5                                  0.520
# 8                                  0.100
# ..                                   ...
# 680                                1.500
# 681                                1.100
# 692                                1.300
# 697                                4.600
# 857                                0.230
#
# [285 rows x 8 columns]

# %%
## Drop 'vx', 'vy', 'vz' columns
fireball_df.pop('vz')
fireball_df
# Out:
#     Peak Brightness Date/Time (UT) Latitude (deg.) Longitude (deg.)  \
# 0              2023-04-01 00:02:03           16.8S            76.0E
# 3              2023-03-03 02:53:54           40.1N            87.4E
# 4              2023-02-19 06:15:34            7.9N           109.9E
# 5              2023-02-14 22:55:25           48.0S            53.3W
# 8              2023-01-17 06:56:59           33.1N           173.7W
# ..                             ...             ...              ...
# 680            2004-04-22 04:21:49           44.3S            83.3E
# 681            2004-04-06 03:24:49           12.0S           162.8E
# 692            2003-11-10 13:54:06           64.5S           136.2E
# 697            2003-09-27 12:59:02           21.0N            86.6E
# 857            1998-01-04 23:00:27           35.1S            33.4E
#
#      Altitude (km)  Velocity (km/s)  Total Radiated Energy (J)  \
# 0             61.8             46.4               2.400000e+10
# 3             32.0             25.3               6.400000e+10
# 4             37.0             23.0               2.030000e+11
# 5             32.3             15.6               1.840000e+11
# 8             38.0             14.2               2.900000e+10
# ..             ...              ...                        ...
# 680           29.6             16.3               6.240000e+11
# 681           35.0             25.6               4.330000e+11
# 692           23.0             20.1               5.180000e+11
# 697           26.0             18.2               2.150000e+12
# 857           30.0             17.1               7.400000e+10
#
#      Calculated Total Impact Energy (kt)
# 0                                  0.086
# 3                                  0.200
# 4                                  0.570
# 5                                  0.520
# 8                                  0.100
# ..                                   ...
# 680                                1.500
# 681                                1.100
# 692                                1.300
# 697                                4.600
# 857                                0.230
#
# [285 rows x 7 columns]

# %%
# Split 'Peak Brightness Date/Time (UT)' into two columns: 'Peak Brightness Date' and 'Peak Brightness Time (UT)'
new_cols = fireball_df['Peak Brightness Date/Time (UT)'].str.split(expand=True)

# Rename the columns
new_cols.columns = ['Dates', 'Times (UT)']

# Concatenate the new DataFramewith the original data
fireball_df = pd.concat([fireball_df, new_cols], axis=1)

# Drop the orginal column 
fireball_df.drop('Peak Brightness Date/Time (UT)', axis=1, inplace=True)

# View the table
fireball_df
# Out:
#     Latitude (deg.) Longitude (deg.)  Altitude (km)  Velocity (km/s)  \
# 0             16.8S            76.0E           61.8             46.4
# 3             40.1N            87.4E           32.0             25.3
# 4              7.9N           109.9E           37.0             23.0
# 5             48.0S            53.3W           32.3             15.6
# 8             33.1N           173.7W           38.0             14.2
# ..              ...              ...            ...              ...
# 680           44.3S            83.3E           29.6             16.3
# 681           12.0S           162.8E           35.0             25.6
# 692           64.5S           136.2E           23.0             20.1
# 697           21.0N            86.6E           26.0             18.2
# 857           35.1S            33.4E           30.0             17.1
#
#      Total Radiated Energy (J)  Calculated Total Impact Energy (kt)  \
# 0                 2.400000e+10                                0.086
# 3                 6.400000e+10                                0.200
# 4                 2.030000e+11                                0.570
# 5                 1.840000e+11                                0.520
# 8                 2.900000e+10                                0.100
# ..                         ...                                  ...
# 680               6.240000e+11                                1.500
# 681               4.330000e+11                                1.100
# 692               5.180000e+11                                1.300
# 697               2.150000e+12                                4.600
# 857               7.400000e+10                                0.230
#
#           Dates Times (UT)
# 0    2023-04-01   00:02:03
# 3    2023-03-03   02:53:54
# 4    2023-02-19   06:15:34
# 5    2023-02-14   22:55:25
# 8    2023-01-17   06:56:59
# ..          ...        ...
# 680  2004-04-22   04:21:49
# 681  2004-04-06   03:24:49
# 692  2003-11-10   13:54:06
# 697  2003-09-27   12:59:02
# 857  1998-01-04   23:00:27
#
# [285 rows x 8 columns]

# %%
# Split 'Peak Brightness Time (UT)' into 'hours', 'minutes', and 'seconds'
for index, row in fireball_df.iterrows():
    hour, minute, second = row['Times (UT)'].split(':')
    fireball_df.loc[index, 'hour'] = int(hour)
    fireball_df.loc[index, 'minute'] = int(minute)
    fireball_df.loc[index, 'second'] = int(second)
    
fireball_df
# Out:
#     Latitude (deg.) Longitude (deg.)  Altitude (km)  Velocity (km/s)  \
# 0             16.8S            76.0E           61.8             46.4
# 3             40.1N            87.4E           32.0             25.3
# 4              7.9N           109.9E           37.0             23.0
# 5             48.0S            53.3W           32.3             15.6
# 8             33.1N           173.7W           38.0             14.2
# ..              ...              ...            ...              ...
# 680           44.3S            83.3E           29.6             16.3
# 681           12.0S           162.8E           35.0             25.6
# 692           64.5S           136.2E           23.0             20.1
# 697           21.0N            86.6E           26.0             18.2
# 857           35.1S            33.4E           30.0             17.1
#
#      Total Radiated Energy (J)  Calculated Total Impact Energy (kt)  \
# 0                 2.400000e+10                                0.086
# 3                 6.400000e+10                                0.200
# 4                 2.030000e+11                                0.570
# 5                 1.840000e+11                                0.520
# 8                 2.900000e+10                                0.100
# ..                         ...                                  ...
# 680               6.240000e+11                                1.500
# 681               4.330000e+11                                1.100
# 692               5.180000e+11                                1.300
# 697               2.150000e+12                                4.600
# 857               7.400000e+10                                0.230
#
#           Dates Times (UT)  hour  minute  second
# 0    2023-04-01   00:02:03   0.0     2.0     3.0
# 3    2023-03-03   02:53:54   2.0    53.0    54.0
# 4    2023-02-19   06:15:34   6.0    15.0    34.0
# 5    2023-02-14   22:55:25  22.0    55.0    25.0
# 8    2023-01-17   06:56:59   6.0    56.0    59.0
# ..          ...        ...   ...     ...     ...
# 680  2004-04-22   04:21:49   4.0    21.0    49.0
# 681  2004-04-06   03:24:49   3.0    24.0    49.0
# 692  2003-11-10   13:54:06  13.0    54.0     6.0
# 697  2003-09-27   12:59:02  12.0    59.0     2.0
# 857  1998-01-04   23:00:27  23.0     0.0    27.0
#
# [285 rows x 11 columns]

# %%
# Convert all 'hours', 'minutes', 'seconds' into all minutes
fireball_df['total_minutes'] = fireball_df['hour'] * 60 + fireball_df['minute'] + fireball_df['second'] / 60

# Drop the orginal columns 'hours', 'minutes', 'seconds' 
fireball_df = fireball_df.drop(columns=['hour', 'minute', 'second'])

# View the table
fireball_df
# Out:
#     Latitude (deg.) Longitude (deg.)  Altitude (km)  Velocity (km/s)  \
# 0             16.8S            76.0E           61.8             46.4
# 3             40.1N            87.4E           32.0             25.3
# 4              7.9N           109.9E           37.0             23.0
# 5             48.0S            53.3W           32.3             15.6
# 8             33.1N           173.7W           38.0             14.2
# ..              ...              ...            ...              ...
# 680           44.3S            83.3E           29.6             16.3
# 681           12.0S           162.8E           35.0             25.6
# 692           64.5S           136.2E           23.0             20.1
# 697           21.0N            86.6E           26.0             18.2
# 857           35.1S            33.4E           30.0             17.1
#
#      Total Radiated Energy (J)  Calculated Total Impact Energy (kt)  \
# 0                 2.400000e+10                                0.086
# 3                 6.400000e+10                                0.200
# 4                 2.030000e+11                                0.570
# 5                 1.840000e+11                                0.520
# 8                 2.900000e+10                                0.100
# ..                         ...                                  ...
# 680               6.240000e+11                                1.500
# 681               4.330000e+11                                1.100
# 692               5.180000e+11                                1.300
# 697               2.150000e+12                                4.600
# 857               7.400000e+10                                0.230
#
#           Dates Times (UT)  total_minutes
# 0    2023-04-01   00:02:03       2.050000
# 3    2023-03-03   02:53:54     173.900000
# 4    2023-02-19   06:15:34     375.566667
# 5    2023-02-14   22:55:25    1375.416667
# 8    2023-01-17   06:56:59     416.983333
# ..          ...        ...            ...
# 680  2004-04-22   04:21:49     261.816667
# 681  2004-04-06   03:24:49     204.816667
# 692  2003-11-10   13:54:06     834.100000
# 697  2003-09-27   12:59:02     779.033333
# 857  1998-01-04   23:00:27    1380.450000
#
# [285 rows x 9 columns]

# %%
for index, row in fireball_df.iterrows():
    try:
        hour, minute, second = row['Times (UT)'].split(':')
        df.loc[index, 'hour'] = int(hour)
        df.loc[index, 'minute'] = int(minute)
        df.loc[index, 'second'] = int(second)
    except:
        print(f"Error processing row {index}")

fireball_df
# Out:
#     Latitude (deg.) Longitude (deg.)  Altitude (km)  Velocity (km/s)  \
# 0             16.8S            76.0E           61.8             46.4
# 3             40.1N            87.4E           32.0             25.3
# 4              7.9N           109.9E           37.0             23.0
# 5             48.0S            53.3W           32.3             15.6
# 8             33.1N           173.7W           38.0             14.2
# ..              ...              ...            ...              ...
# 680           44.3S            83.3E           29.6             16.3
# 681           12.0S           162.8E           35.0             25.6
# 692           64.5S           136.2E           23.0             20.1
# 697           21.0N            86.6E           26.0             18.2
# 857           35.1S            33.4E           30.0             17.1
#
#      Total Radiated Energy (J)  Calculated Total Impact Energy (kt)  \
# 0                 2.400000e+10                                0.086
# 3                 6.400000e+10                                0.200
# 4                 2.030000e+11                                0.570
# 5                 1.840000e+11                                0.520
# 8                 2.900000e+10                                0.100
# ..                         ...                                  ...
# 680               6.240000e+11                                1.500
# 681               4.330000e+11                                1.100
# 692               5.180000e+11                                1.300
# 697               2.150000e+12                                4.600
# 857               7.400000e+10                                0.230
#
#           Dates Times (UT)  total_minutes
# 0    2023-04-01   00:02:03       2.050000
# 3    2023-03-03   02:53:54     173.900000
# 4    2023-02-19   06:15:34     375.566667
# 5    2023-02-14   22:55:25    1375.416667
# 8    2023-01-17   06:56:59     416.983333
# ..          ...        ...            ...
# 680  2004-04-22   04:21:49     261.816667
# 681  2004-04-06   03:24:49     204.816667
# 692  2003-11-10   13:54:06     834.100000
# 697  2003-09-27   12:59:02     779.033333
# 857  1998-01-04   23:00:27    1380.450000
#
# [285 rows x 9 columns]

# %% [markdown]
# # 3. Latitude and Longitude Cleaning

# %%
## Because the dataset provides us with latitude and longitude for fireballs in degrees, we have to change it into coordinates. 
test = df.iloc[0]
test
# Out:
# Peak Brightness Date/Time (UT)         2023-04-01 00:02:03
# Latitude (deg.)                                      16.8S
# Longitude (deg.)                                     76.0E
# Altitude (km)                                         61.8
# Velocity (km/s)                                       46.4
# vx                                                    21.4
# vy                                                   -40.6
# vz                                                     7.1
# Total Radiated Energy (J)                    24000000000.0
# Calculated Total Impact Energy (kt)                  0.086
# hour                                                   0.0
# minute                                                 2.0
# second                                                 3.0
# Name: 0, dtype: object

# %%
# Parse through the first row of "Latitude (deg.)" data
parse(test["Latitude (deg.)"])
# Out:
# -16.8

# %%
# Parse through the first row of "Longitude (deg.)" data
parse(test["Longitude (deg.)"])
# Out:
# 76.0

# %%
# Parse through and clean all of 'fireball_lat' column
fireball_df2= fireball_df.loc[~(df["Latitude (deg.)"].isna())]
fireball_df2
# Out:
#     Latitude (deg.) Longitude (deg.)  Altitude (km)  Velocity (km/s)  \
# 0             16.8S            76.0E           61.8             46.4
# 3             40.1N            87.4E           32.0             25.3
# 4              7.9N           109.9E           37.0             23.0
# 5             48.0S            53.3W           32.3             15.6
# 8             33.1N           173.7W           38.0             14.2
# ..              ...              ...            ...              ...
# 680           44.3S            83.3E           29.6             16.3
# 681           12.0S           162.8E           35.0             25.6
# 692           64.5S           136.2E           23.0             20.1
# 697           21.0N            86.6E           26.0             18.2
# 857           35.1S            33.4E           30.0             17.1
#
#      Total Radiated Energy (J)  Calculated Total Impact Energy (kt)  \
# 0                 2.400000e+10                                0.086
# 3                 6.400000e+10                                0.200
# 4                 2.030000e+11                                0.570
# 5                 1.840000e+11                                0.520
# 8                 2.900000e+10                                0.100
# ..                         ...                                  ...
# 680               6.240000e+11                                1.500
# 681               4.330000e+11                                1.100
# 692               5.180000e+11                                1.300
# 697               2.150000e+12                                4.600
# 857               7.400000e+10                                0.230
#
#           Dates Times (UT)  total_minutes
# 0    2023-04-01   00:02:03       2.050000
# 3    2023-03-03   02:53:54     173.900000
# 4    2023-02-19   06:15:34     375.566667
# 5    2023-02-14   22:55:25    1375.416667
# 8    2023-01-17   06:56:59     416.983333
# ..          ...        ...            ...
# 680  2004-04-22   04:21:49     261.816667
# 681  2004-04-06   03:24:49     204.816667
# 692  2003-11-10   13:54:06     834.100000
# 697  2003-09-27   12:59:02     779.033333
# 857  1998-01-04   23:00:27    1380.450000
#
# [285 rows x 9 columns]

# %%
# Create a new column that has the cleaned latitude coordinates and display it
fireball_df2["lat"] = fireball_df2["Latitude (deg.)"].map(lambda l: parse(l))

# Drop the orginal column 'Latitude (deg.)'
fireball_df2 = fireball_df2.drop(columns=['Latitude (deg.)'])
fireball_df2
# Out:
#     Longitude (deg.)  Altitude (km)  Velocity (km/s)  \
# 0              76.0E           61.8             46.4
# 3              87.4E           32.0             25.3
# 4             109.9E           37.0             23.0
# 5              53.3W           32.3             15.6
# 8             173.7W           38.0             14.2
# ..               ...            ...              ...
# 680            83.3E           29.6             16.3
# 681           162.8E           35.0             25.6
# 692           136.2E           23.0             20.1
# 697            86.6E           26.0             18.2
# 857            33.4E           30.0             17.1
#
#      Total Radiated Energy (J)  Calculated Total Impact Energy (kt)  \
# 0                 2.400000e+10                                0.086
# 3                 6.400000e+10                                0.200
# 4                 2.030000e+11                                0.570
# 5                 1.840000e+11                                0.520
# 8                 2.900000e+10                                0.100
# ..                         ...                                  ...
# 680               6.240000e+11                                1.500
# 681               4.330000e+11                                1.100
# 692               5.180000e+11                                1.300
# 697               2.150000e+12                                4.600
# 857               7.400000e+10                                0.230
#
#           Dates Times (UT)  total_minutes   lat
# 0    2023-04-01   00:02:03       2.050000 -16.8
# 3    2023-03-03   02:53:54     173.900000  40.1
# 4    2023-02-19   06:15:34     375.566667   7.9
# 5    2023-02-14   22:55:25    1375.416667 -48.0
# 8    2023-01-17   06:56:59     416.983333  33.1
# ..          ...        ...            ...   ...
# 680  2004-04-22   04:21:49     261.816667 -44.3
# 681  2004-04-06   03:24:49     204.816667 -12.0
# 692  2003-11-10   13:54:06     834.100000 -64.5
# 697  2003-09-27   12:59:02     779.033333  21.0
# 857  1998-01-04   23:00:27    1380.450000 -35.1
#
# [285 rows x 9 columns]

# %%
# Do the math (multiply the minutes with the latitude) to get coordinates for latitude
fireball_df2['latitude'] = fireball_df2['total_minutes'] * fireball_df2['lat']

# Drop 'lat' column
fireball_df2 = fireball_df2.drop(columns=['lat'])
fireball_df2
# Out:
#     Longitude (deg.)  Altitude (km)  Velocity (km/s)  \
# 0              76.0E           61.8             46.4
# 3              87.4E           32.0             25.3
# 4             109.9E           37.0             23.0
# 5              53.3W           32.3             15.6
# 8             173.7W           38.0             14.2
# ..               ...            ...              ...
# 680            83.3E           29.6             16.3
# 681           162.8E           35.0             25.6
# 692           136.2E           23.0             20.1
# 697            86.6E           26.0             18.2
# 857            33.4E           30.0             17.1
#
#      Total Radiated Energy (J)  Calculated Total Impact Energy (kt)  \
# 0                 2.400000e+10                                0.086
# 3                 6.400000e+10                                0.200
# 4                 2.030000e+11                                0.570
# 5                 1.840000e+11                                0.520
# 8                 2.900000e+10                                0.100
# ..                         ...                                  ...
# 680               6.240000e+11                                1.500
# 681               4.330000e+11                                1.100
# 692               5.180000e+11                                1.300
# 697               2.150000e+12                                4.600
# 857               7.400000e+10                                0.230
#
#           Dates Times (UT)  total_minutes      latitude
# 0    2023-04-01   00:02:03       2.050000    -34.440000
# 3    2023-03-03   02:53:54     173.900000   6973.390000
# 4    2023-02-19   06:15:34     375.566667   2966.976667
# 5    2023-02-14   22:55:25    1375.416667 -66020.000000
# 8    2023-01-17   06:56:59     416.983333  13802.148333
# ..          ...        ...            ...           ...
# 680  2004-04-22   04:21:49     261.816667 -11598.478333
# 681  2004-04-06   03:24:49     204.816667  -2457.800000
# 692  2003-11-10   13:54:06     834.100000 -53799.450000
# 697  2003-09-27   12:59:02     779.033333  16359.700000
# 857  1998-01-04   23:00:27    1380.450000 -48453.795000
#
# [285 rows x 9 columns]

# %%
# Create a new column containing cleaned longitude coordinates and display it
fireball_df2["long"] = fireball_df2["Longitude (deg.)"].map(lambda l: parse(l))

# Drop the orginal column 'Longitude (deg.)'
fireball_df2 = fireball_df2.drop(columns=['Longitude (deg.)'])
fireball_df2
# Out:
#      Altitude (km)  Velocity (km/s)  Total Radiated Energy (J)  \
# 0             61.8             46.4               2.400000e+10
# 3             32.0             25.3               6.400000e+10
# 4             37.0             23.0               2.030000e+11
# 5             32.3             15.6               1.840000e+11
# 8             38.0             14.2               2.900000e+10
# ..             ...              ...                        ...
# 680           29.6             16.3               6.240000e+11
# 681           35.0             25.6               4.330000e+11
# 692           23.0             20.1               5.180000e+11
# 697           26.0             18.2               2.150000e+12
# 857           30.0             17.1               7.400000e+10
#
#      Calculated Total Impact Energy (kt)       Dates Times (UT)  \
# 0                                  0.086  2023-04-01   00:02:03
# 3                                  0.200  2023-03-03   02:53:54
# 4                                  0.570  2023-02-19   06:15:34
# 5                                  0.520  2023-02-14   22:55:25
# 8                                  0.100  2023-01-17   06:56:59
# ..                                   ...         ...        ...
# 680                                1.500  2004-04-22   04:21:49
# 681                                1.100  2004-04-06   03:24:49
# 692                                1.300  2003-11-10   13:54:06
# 697                                4.600  2003-09-27   12:59:02
# 857                                0.230  1998-01-04   23:00:27
#
#      total_minutes      latitude   long
# 0         2.050000    -34.440000   76.0
# 3       173.900000   6973.390000   87.4
# 4       375.566667   2966.976667  109.9
# 5      1375.416667 -66020.000000  -53.3
# 8       416.983333  13802.148333 -173.7
# ..             ...           ...    ...
# 680     261.816667 -11598.478333   83.3
# 681     204.816667  -2457.800000  162.8
# 692     834.100000 -53799.450000  136.2
# 697     779.033333  16359.700000   86.6
# 857    1380.450000 -48453.795000   33.4
#
# [285 rows x 9 columns]

# %%
# Do the math (multiply the minutes with the longitude) to get coordinates for longitude
fireball_df2['longitude'] = fireball_df2['total_minutes'] * fireball_df2['long']

# Drop 'lat' column
fireball_df2 = fireball_df2.drop(columns=['long'])
fireball_df2
# Out:
#      Altitude (km)  Velocity (km/s)  Total Radiated Energy (J)  \
# 0             61.8             46.4               2.400000e+10
# 3             32.0             25.3               6.400000e+10
# 4             37.0             23.0               2.030000e+11
# 5             32.3             15.6               1.840000e+11
# 8             38.0             14.2               2.900000e+10
# ..             ...              ...                        ...
# 680           29.6             16.3               6.240000e+11
# 681           35.0             25.6               4.330000e+11
# 692           23.0             20.1               5.180000e+11
# 697           26.0             18.2               2.150000e+12
# 857           30.0             17.1               7.400000e+10
#
#      Calculated Total Impact Energy (kt)       Dates Times (UT)  \
# 0                                  0.086  2023-04-01   00:02:03
# 3                                  0.200  2023-03-03   02:53:54
# 4                                  0.570  2023-02-19   06:15:34
# 5                                  0.520  2023-02-14   22:55:25
# 8                                  0.100  2023-01-17   06:56:59
# ..                                   ...         ...        ...
# 680                                1.500  2004-04-22   04:21:49
# 681                                1.100  2004-04-06   03:24:49
# 692                                1.300  2003-11-10   13:54:06
# 697                                4.600  2003-09-27   12:59:02
# 857                                0.230  1998-01-04   23:00:27
#
#      total_minutes      latitude      longitude
# 0         2.050000    -34.440000     155.800000
# 3       173.900000   6973.390000   15198.860000
# 4       375.566667   2966.976667   41274.776667
# 5      1375.416667 -66020.000000  -73309.708333
# 8       416.983333  13802.148333  -72430.005000
# ..             ...           ...            ...
# 680     261.816667 -11598.478333   21809.328333
# 681     204.816667  -2457.800000   33344.153333
# 692     834.100000 -53799.450000  113604.420000
# 697     779.033333  16359.700000   67464.286667
# 857    1380.450000 -48453.795000   46107.030000
#
# [285 rows x 9 columns]

# %%
# Add another column combining the latitude and longitude
fireball_df2 = fireball_df2.assign(geolocation=[*zip(fireball_df2.latitude, fireball_df2.longitude)])
fireball_df2
# Out:
#      Altitude (km)  Velocity (km/s)  Total Radiated Energy (J)  \
# 0             61.8             46.4               2.400000e+10
# 3             32.0             25.3               6.400000e+10
# 4             37.0             23.0               2.030000e+11
# 5             32.3             15.6               1.840000e+11
# 8             38.0             14.2               2.900000e+10
# ..             ...              ...                        ...
# 680           29.6             16.3               6.240000e+11
# 681           35.0             25.6               4.330000e+11
# 692           23.0             20.1               5.180000e+11
# 697           26.0             18.2               2.150000e+12
# 857           30.0             17.1               7.400000e+10
#
#      Calculated Total Impact Energy (kt)       Dates Times (UT)  \
# 0                                  0.086  2023-04-01   00:02:03
# 3                                  0.200  2023-03-03   02:53:54
# 4                                  0.570  2023-02-19   06:15:34
# 5                                  0.520  2023-02-14   22:55:25
# 8                                  0.100  2023-01-17   06:56:59
# ..                                   ...         ...        ...
# 680                                1.500  2004-04-22   04:21:49
# 681                                1.100  2004-04-06   03:24:49
# 692                                1.300  2003-11-10   13:54:06
# 697                                4.600  2003-09-27   12:59:02
# 857                                0.230  1998-01-04   23:00:27
#
#      total_minutes      latitude      longitude  \
# 0         2.050000    -34.440000     155.800000
# 3       173.900000   6973.390000   15198.860000
# 4       375.566667   2966.976667   41274.776667
# 5      1375.416667 -66020.000000  -73309.708333
# 8       416.983333  13802.148333  -72430.005000
# ..             ...           ...            ...
# 680     261.816667 -11598.478333   21809.328333
# 681     204.816667  -2457.800000   33344.153333
# 692     834.100000 -53799.450000  113604.420000
# 697     779.033333  16359.700000   67464.286667
# 857    1380.450000 -48453.795000   46107.030000
#
#                                   geolocation
# 0                (-34.44, 155.79999999999998)
# 3                         (6973.39, 15198.86)
# 4     (2966.976666666667, 41274.776666666665)
# 5              (-66020.0, -73309.70833333333)
# 8            (13802.148333333334, -72430.005)
# ..                                        ...
# 680  (-11598.478333333333, 21809.32833333333)
# 681             (-2457.8, 33344.153333333335)
# 692          (-53799.450000000004, 113604.42)
# 697   (16359.699999999999, 67464.28666666667)
# 857           (-48453.795000000006, 46107.03)
#
# [285 rows x 10 columns]

# %%
# Convert 'geolocation' to a string
fireball_df2['geolocation'] = fireball_df2['geolocation'].astype(str)

# %%
print(fireball_df2.dtypes)
# Out:
# Altitude (km)                          float64
# Velocity (km/s)                        float64
# Total Radiated Energy (J)              float64
# Calculated Total Impact Energy (kt)    float64
# Dates                                   object
# Times (UT)                              object
# total_minutes                          float64
# latitude                               float64
# longitude                              float64
# geolocation                             object
# dtype: object

# %% [markdown]
# ### 2.2 Filter out Fireballs that Fell Outside USA

# %%
## We are only looking at fireballs that fell or were reported within the USA, therefore we need to figure out what countries that fell over utilizing GeoLocation as the key.

fireball_df2.geolocation = (
    fireball_df2
    .geolocation
    .str
    .strip()
    .replace(
        {
            '\(':'',
            '\)':'',
            ' ':''
        },
        regex=True
    )
)
fireball_df2
# Out:
#      Altitude (km)  Velocity (km/s)  Total Radiated Energy (J)  \
# 0             61.8             46.4               2.400000e+10
# 3             32.0             25.3               6.400000e+10
# 4             37.0             23.0               2.030000e+11
# 5             32.3             15.6               1.840000e+11
# 8             38.0             14.2               2.900000e+10
# ..             ...              ...                        ...
# 680           29.6             16.3               6.240000e+11
# 681           35.0             25.6               4.330000e+11
# 692           23.0             20.1               5.180000e+11
# 697           26.0             18.2               2.150000e+12
# 857           30.0             17.1               7.400000e+10
#
#      Calculated Total Impact Energy (kt)       Dates Times (UT)  \
# 0                                  0.086  2023-04-01   00:02:03
# 3                                  0.200  2023-03-03   02:53:54
# 4                                  0.570  2023-02-19   06:15:34
# 5                                  0.520  2023-02-14   22:55:25
# 8                                  0.100  2023-01-17   06:56:59
# ..                                   ...         ...        ...
# 680                                1.500  2004-04-22   04:21:49
# 681                                1.100  2004-04-06   03:24:49
# 692                                1.300  2003-11-10   13:54:06
# 697                                4.600  2003-09-27   12:59:02
# 857                                0.230  1998-01-04   23:00:27
#
#      total_minutes      latitude      longitude  \
# 0         2.050000    -34.440000     155.800000
# 3       173.900000   6973.390000   15198.860000
# 4       375.566667   2966.976667   41274.776667
# 5      1375.416667 -66020.000000  -73309.708333
# 8       416.983333  13802.148333  -72430.005000
# ..             ...           ...            ...
# 680     261.816667 -11598.478333   21809.328333
# 681     204.816667  -2457.800000   33344.153333
# 692     834.100000 -53799.450000  113604.420000
# 697     779.033333  16359.700000   67464.286667
# 857    1380.450000 -48453.795000   46107.030000
#
#                                geolocation
# 0                -34.44,155.79999999999998
# 3                         6973.39,15198.86
# 4     2966.976666666667,41274.776666666665
# 5              -66020.0,-73309.70833333333
# 8            13802.148333333334,-72430.005
# ..                                     ...
# 680  -11598.478333333333,21809.32833333333
# 681             -2457.8,33344.153333333335
# 692          -53799.450000000004,113604.42
# 697   16359.699999999999,67464.28666666667
# 857           -48453.795000000006,46107.03
#
# [285 rows x 10 columns]

# %%
# Next, we want to narrow down the key to only unique locations
geo_key = pd.DataFrame(fireball_df2['geolocation'].unique(),columns=['geolocation'])
geo_key
# Out:
#                                geolocation
# 0                -34.44,155.79999999999998
# 1                         6973.39,15198.86
# 2     2966.976666666667,41274.776666666665
# 3              -66020.0,-73309.70833333333
# 4            13802.148333333334,-72430.005
# ..                                     ...
# 280  -11598.478333333333,21809.32833333333
# 281             -2457.8,33344.153333333335
# 282          -53799.450000000004,113604.42
# 283   16359.699999999999,67464.28666666667
# 284           -48453.795000000006,46107.03
#
# [285 rows x 1 columns]

# %%
# Set the pause duration between api requests
pause = 0.1

# %%
# Set up a function that accepts a latitude,longitude string, sends it to the Google API, and returns the location API result
def geocode(latlong):
    time.sleep(pause) #pause for some duration before each request, to not hammer their server
    url = 'https://maps.googleapis.com/maps/api/geocode/json?latlng={}&sensor=false&key='+ api_key #api url with placeholders
    request = url.format(latlong) #fill in the placeholder with a variable
    response = requests.get(request) #send the request to the server and get the response
    data = response.json() #convert the response json string into a dict
    
    if len(data['results']) > 0: #if google was able to geolocate our address, extract formatted address from result
        return data['results'][0]['formatted_address']

# %%
# for each value in the GeoLocation column, geocode it, save results as new df column
geo_key['Address'] = geo_key['geolocation'].map(geocode)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15584\829011847.py in <module>
#       1 # for each value in the GeoLocation column, geocode it, save results as new df column
# ----> 2 geo_key['Address'] = geo_key['geolocation'].map(geocode)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in map(self, arg, na_action)
#    4235         dtype: object
#    4236         """
# -> 4237         new_values = self._map_values(arg, na_action=na_action)
#    4238         return self._constructor(new_values, index=self.index).__finalize__(
#    4239             self, method="map"
#
# ~\anaconda3\lib\site-packages\pandas\core\base.py in _map_values(self, mapper, na_action)
#     878
#     879         # mapper is a function
# --> 880         new_values = map_f(values, mapper)
#     881
#     882         return new_values
#
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\AppData\Local\Temp\ipykernel_15584\997056594.py in geocode(latlong)
#       2 def geocode(latlong):
#       3     time.sleep(pause) #pause for some duration before each request, to not hammer their server
# ----> 4     url = 'https://maps.googleapis.com/maps/api/geocode/json?latlng={}&sensor=false&key='+ api_key #api url with placeholders
#       5     request = url.format(latlong) #fill in the placeholder with a variable
#       6     response = requests.get(request) #send the request to the server and get the response
#
# NameError: name 'api_key' is not defined

# %%
#Drop any incomplete sets
geo_key=geo_key.dropna()

# Check how it looks
geo_key.head()
# Out:
#                             geolocation
# 0             -34.44,155.79999999999998
# 1                      6973.39,15198.86
# 2  2966.976666666667,41274.776666666665
# 3           -66020.0,-73309.70833333333
# 4         13802.148333333334,-72430.005

# %%
# Filter out all non-USA results
country = 'USA'
geo_key2=geo_key[geo_key['Address'].str.contains(country)]
geo_key2['Country']='USA'
geo_key2.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Address'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15584\2735779226.py in <module>
#       1 # Filter out all non-USA results
#       2 country = 'USA'
# ----> 3 geo_key2=geo_key[geo_key['Address'].str.contains(country)]
#       4 geo_key2['Country']='USA'
#       5 geo_key2.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Address'

# %%
#Merge the key back in with the dataset using an inner join to filter out non-USA meteorites
df3 = df2.merge(geo_key2, on='GeoLocation', how='inner')

#Drop columns not needed from key 
df3 = (df3.drop(['GeoLocation', 'Country'], axis=1).dropna())
df3.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15584\780089021.py in <module>
#       1 #Merge the key back in with the dataset using an inner join to filter out non-USA meteorites
# ----> 2 df3 = df2.merge(geo_key2, on='GeoLocation', how='inner')
#       3
#       4 #Drop columns not needed from key
#       5 df3 = (df3.drop(['GeoLocation', 'Country'], axis=1).dropna())
#
# NameError: name 'df2' is not defined

# %%
#Save as JSON
df3.to_json('Resources/Fireball_Peaks.json')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15584\1895857206.py in <module>
#       1 #Save as JSON
# ----> 2 df3.to_json('Resources/Fireball_Peaks.json')
#
# NameError: name 'df3' is not defined

# %%
# Set the Coordinate Reference System (CRS) to the WGS84 (epsg:4326) latitude-longitude projection 
# fyi: CRS tells Python how coordinates relate to places on the Earth
#      https://spatialreference.org/ref/epsg/4326/
#      https://en.wikipedia.org/wiki/World_Geodetic_System
crs={'init':'epsg:4326'}

# Create a GeoDataFrame using the zip code coordinates
geo_df=gpd.GeoDataFrame(df3,crs=crs,geometry=gpd.points_from_xy(df3['longitude'], df3['latitude']))

# Check dataframe
geo_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15584\1276104434.py in <module>
#       6
#       7 # Create a GeoDataFrame using the zip code coordinates
# ----> 8 geo_df=gpd.GeoDataFrame(df3,crs=crs,geometry=gpd.points_from_xy(df3['longitude'], df3['latitude']))
#       9
#      10 # Check dataframe
#
# NameError: name 'gpd' is not defined

# %%
#Save as a GeoJSON
geo_df.to_file('Project-3-/Resources/Fireball_Peaks.geojson', driver="GeoJSON")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15584\1141216307.py in <module>
#       1 #Save as a GeoJSON
# ----> 2 geo_df.to_file('Project-3-/Resources/Fireball_Peaks.geojson', driver="GeoJSON")
#
# NameError: name 'geo_df' is not defined
